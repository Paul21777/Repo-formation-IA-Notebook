# %%
import pandas as pd
import atoti as tt

session = tt.Session(
)

sales_table = session.read_csv(
    "source_entrainement_fichier/sales.csv"
)

shops_table = session.read_csv(
    "source_entrainement_fichier/shops.csv"
)

products_table = session.read_csv(
    "source_entrainement_fichier/products.csv"
)

# Import des CSV dans un df
sales_df = pd.read_csv("source_entrainement_fichier/sales.csv")

shops_df = pd.read_csv("source_entrainement_fichier/shops.csv")

products_df = pd.read_csv("source_entrainement_fichier/products.csv")
# Out:
# Closing existing "Unnamed" session to create the new one.
# <class 'pandas.core.frame.DataFrame'>

# %%
cube = session.create_cube(sales_table, name="Sales")

# %%
session.widget
# Out:
# Open the notebook in JupyterLab with the Atoti JupyterLab extension enabled to build this widget.

# %%
cube = session.create_cube(shops_table, name="Shops")

# %%
session.widget
# Out:
# Open the notebook in JupyterLab with the Atoti JupyterLab extension enabled to build this widget.
